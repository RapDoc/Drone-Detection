# %% [markdown]
# Installed the model "YOLO"

# %%
# !pip install ultralytics --upgrade -q
from ultralytics import YOLO
import os
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 53.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 44.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 28.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 78.0 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# ...

# %% [markdown]
# IMPORTING THE DATASET

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/Drone"
# Out:
#  best.pt  'Dataset 2.zip'

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/Drone/best.pt")

# %%
# !ls "/content"
# Out:
# drive  sample_data

# %%
# !unzip /content/drive/MyDrive/Drone/'Dataset 2'.zip -d /content/Dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Dataset/Dataset/train/images/0191.jpg
#   inflating: /content/Dataset/__MACOSX/Dataset/train/images/._0191.jpg
#   inflating: /content/Dataset/Dataset/train/images/train_20191206080308370422.jpg
#   inflating: /content/Dataset/__MACOSX/Dataset/train/images/._train_20191206080308370422.jpg
#   inflating: /content/Dataset/Dataset/train/images/0185.jpg
#   inflating: /content/Dataset/__MACOSX/Dataset/train/images/._0185.jpg
#   inflating: /content/Dataset/Dataset/train/images/train_20191206080607084204.jpg
#   inflating: /content/Dataset/__MACOSX/Dataset/train/images/._train_20191206080607084204.jpg
#   inflating: /content/Dataset/Dataset/train/images/pic_1130_jpg.rf.f072df8fdc0274254a5a2e4005068cc8.jpg
#   inflating: /content/Dataset/__MACOSX/Dataset/train/images/._pic_1130_jpg.rf.f072df8fdc0274254a5a2e4005068cc8.jpg
# ...

# %%
model.val(data="/content/Dataset/Dataset/data.yaml")
# Out:
# Ultralytics 8.3.155 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 92 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 13.9MB/s]
# val: Fast image access ✅ (ping: 0.0±0.1 ms, read: 438.8±228.0 MB/s, size: 28.1 KB)
# val: Scanning /content/Dataset/Dataset/valid/labels... 150 images, 0 backgrounds, 0 corrupt: 100%|██████████| 150/150 [00:00<00:00, 1328.53it/s]
# val: New cache created: /content/Dataset/Dataset/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [10:18<00:00, 61.80s/it]
#                    all        150        171      0.751      0.784      0.798      0.438
# Speed: 21.7ms preprocess, 4077.6ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to runs/detect/val
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# ...

# %% [markdown]
# FOR CHECKING PURPOSE

# %%
results = model('/content/Dataset/Dataset/test/images/0016_jpg.rf.9594f37d5e138c8f5928d4d05da214f9.jpg', conf=0.5, show=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/Dataset/Dataset/test/images/0016_jpg.rf.9594f37d5e138c8f5928d4d05da214f9.jpg: 832x832 1 drone, 58.8ms
# Speed: 4.4ms preprocess, 58.8ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 832)

# %%
results = model.predict(
    source="/content/Dataset/Dataset/test/images",  # path to folder or single image
    save=True,
    conf=0.1,
    iou = 0.3,
    imgsz = 2400 # confidence threshold
)
# Out:
# image 1/85 /content/Dataset/Dataset/test/images/0009_jpg.rf.6ae80767368480974d0dc38fbaaa95bd.jpg: 2400x2400 1 drone, 328.9ms
# image 2/85 /content/Dataset/Dataset/test/images/0016_jpg.rf.9594f37d5e138c8f5928d4d05da214f9.jpg: 2400x2400 4 drones, 260.7ms
# image 3/85 /content/Dataset/Dataset/test/images/0034_jpg.rf.00c6126ae809bcfe162b6f6e19ce5aee.jpg: 2400x2400 3 drones, 253.4ms
# image 4/85 /content/Dataset/Dataset/test/images/0046_jpg.rf.1ed00a48d2af76c243d0a80b304cf590.jpg: 2400x2400 (no detections), 260.9ms
# image 5/85 /content/Dataset/Dataset/test/images/0065_jpg.rf.fc22155db9dab4d72656bb6407011b3c.jpg: 2400x2400 2 drones, 260.9ms
# image 6/85 /content/Dataset/Dataset/test/images/0082_jpg.rf.48bed6a9137c02d961eb2d4418e389ce.jpg: 2400x2400 6 drones, 253.6ms
# image 7/85 /content/Dataset/Dataset/test/images/0083_jpg.rf.4f18f9a08084e4289024eaff6f0c3be2.jpg: 2400x2400 5 drones, 258.1ms
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0dd4d9ee-f579-4bc2-9f00-25c69d628f89" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0dd4d9ee-f579-4bc2-9f00-25c69d628f89">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls "/content"
# Out:
# 0014_jpg.rf.8b8f9934d99989485606a8e5ffbeb448.jpg  drive  sample_data
# Dataset						  runs

# %%
results = model.predict(
    source="/content/0014_jpg.rf.8b8f9934d99989485606a8e5ffbeb448",
    device=0,
    save=True,
    project="/content/runs/detect",
    name="drone_test",  # ✅ This creates folder /content/runs/detect/drone_test
    exist_ok=True,       # ✅ Avoids creating drone_test2, drone_test3 etc.
    conf = 0.3,
    imgsz = 2400
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-2950088923> in <cell line: 0>()
# ----> 1 results = model.predict(
#       2     source="/content/0014_jpg.rf.8b8f9934d99989485606a8e5ffbeb448",
#       3     device=0,
#       4     save=True,
#       5     project="/content/runs/detect",
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     553         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     554             self.predictor.set_prompts(prompts)
# --> 555         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     556
#     557     def track(
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
# ...

# %%
from IPython.display import Image, display
display(Image("/content/runs/detect/drone_test/dronessss.jpg"))

# %%
results = model.predict(
    source="/content/Dataset/Dataset/train/images/0001_jpg.rf.19cab5048fb2054efabf423fb8ad8aff.jpg",
    device=0,
    save=True,
    project="/content/Dataset/runs/detect",
    name="drone_test",  # ✅ This creates folder /content/runs/detect/drone_test
    exist_ok=True # ✅ Avoids creating drone_test2, drone_test3 etc.
)

# %%
from IPython.display import Image, display
display(Image("/content/Dataset/runs/detect/drone_test/0001_jpg.rf.19cab5048fb2054efabf423fb8ad8aff.jpg"))

# %%
# !pip install opencv-python
